# %% [markdown]
# # Exploring Ranking Models in Information Retrieval
#
# ## Objective
# Understand the practical implementation and differences between the Vector Space Model and the Binary Independence Model in ranking documents relative to a user query.

# %% [markdown]
# ### Step 1: Data Preprocessing
#
# Ensure that the documents are still loaded and preprocessed from the previous task. The data should be clean and ready for advanced querying.
# Write a function to load and preprocess the text documents from a specified directory. This step involves reading each file, converting the text to lowercase for uniform processing, and storing the results in a dictionary.

# %%
import os
import pandas as pd
from collections import defaultdict

# Define the path to the directory containing the text files
CORPUS_DIR = '../../week01/data'
documents = {}

# Dictionary to store word counts for each document
word_counts = defaultdict(lambda: defaultdict(int))

# %% [markdown]
# ### Step 2:  Vector Space Model (VSM)
#
# Task: Implement a simple Vector Space Model using term frequency.
#
# Requirements:
# * _Document and Query Representation:_ Convert each document and the query into a vector where each dimension corresponds to a term from the corpus. Use simple term frequency for weighting.
# * _Cosine Similarity Calculation:_ Calculate the cosine similarity between the query vector and each document vector.
# * _Ranking:_ Rank the documents based on their cosine similarity scores from highest to lowest.

# %%
# Iterate through each file in the directory
for filename in os.listdir(CORPUS_DIR):
    if filename.endswith('.txt'):
        file_path = os.path.join(CORPUS_DIR, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            document_text = file.read().lower()  # Read and convert to lowercase
            documents[filename] = document_text

            # Count word occurrences in the current document
            words = document_text.split()
            for word in words:
                word_counts[word][filename] += 1

# Create a DataFrame from the word counts
df = pd.DataFrame(word_counts)

# Fill NaN values with 0 (for words not present in some documents)
df.fillna(0, inplace=True)

# Save the DataFrame to a CSV file
# df_word_counts.to_csv('word_counts_per_document.csv')

# Display the DataFrame
print(df)
# Out:
#                                    ﻿the  project  gutenberg  ebook     of  \
# A Room with a View.txt                1       83         25      8   1435
# Chronicles of London Bridge.txt       1       84         25      8   9664
# Winnie-the-Pooh.txt                   1       83         25      8    507
# The Enchanted April.txt               1       83         25      8   1842
# Moby Dick.txt                         1       87         25      8   6682
# ...                                 ...      ...        ...    ...    ...
# The Hound of the Baskervilles.txt     1       83         25      8   1719
# Romeo and Juliet.txt                  1       84         26      8    516
# The Blue Castle- a novel.txt          1       83         25      8   1591
# The Metamorphoses of Ovid.txt         1       83         25      8   5601
# The History of Woman Suffrage.txt     1       86         25      8  23106
#
#                                       a  room  with   view  this  ...  \
# A Room with a View.txt             1281  24.0   496   24.0   248  ...
# Chronicles of London Bridge.txt    2709   6.0  1215  119.0  1030  ...
# Winnie-the-Pooh.txt                 588   4.0   165    0.0   117  ...
# The Enchanted April.txt            1294  48.0   659    2.0   329  ...
# Moby Dick.txt                      4663  17.0  1750   26.0  1277  ...
# ...                                 ...   ...   ...    ...   ...  ...
# The Hound of the Baskervilles.txt  1338  15.0   484    8.0   344  ...
# Romeo and Juliet.txt                539   7.0   299    2.0   243  ...
# The Blue Castle- a novel.txt       1570  34.0   532    2.0   184  ...
# The Metamorphoses of Ovid.txt      2150   4.0  1426    4.0   558  ...
# The History of Woman Suffrage.txt  8270  39.0  2254   34.0  2854  ...
#
#                                    -->classes  #460)  conspicious  1030  \
# A Room with a View.txt                    0.0    0.0          0.0   0.0
# Chronicles of London Bridge.txt           0.0    0.0          0.0   0.0
# Winnie-the-Pooh.txt                       0.0    0.0          0.0   0.0
# The Enchanted April.txt                   0.0    0.0          0.0   0.0
# Moby Dick.txt                             0.0    0.0          0.0   0.0
# ...                                       ...    ...          ...   ...
# The Hound of the Baskervilles.txt         0.0    0.0          0.0   0.0
# Romeo and Juliet.txt                      0.0    0.0          0.0   0.0
# The Blue Castle- a novel.txt              0.0    0.0          0.0   0.0
# The Metamorphoses of Ovid.txt             0.0    0.0          0.0   0.0
# The History of Woman Suffrage.txt         1.0    1.0          1.0   1.0
#
#                                    ocupying  1091  encouragment  \
# A Room with a View.txt                  0.0   0.0           0.0
# Chronicles of London Bridge.txt         0.0   0.0           0.0
# Winnie-the-Pooh.txt                     0.0   0.0           0.0
# The Enchanted April.txt                 0.0   0.0           0.0
# Moby Dick.txt                           0.0   0.0           0.0
# ...                                     ...   ...           ...
# The Hound of the Baskervilles.txt       0.0   0.0           0.0
# Romeo and Juliet.txt                    0.0   0.0           0.0
# The Blue Castle- a novel.txt            0.0   0.0           0.0
# The Metamorphoses of Ovid.txt           0.0   0.0           0.0
# The History of Woman Suffrage.txt       1.0   1.0           1.0
#
#                                    -->encouragement  1094  atorney
# A Room with a View.txt                          0.0   0.0      0.0
# Chronicles of London Bridge.txt                 0.0   0.0      0.0
# Winnie-the-Pooh.txt                             0.0   0.0      0.0
# The Enchanted April.txt                         0.0   0.0      0.0
# Moby Dick.txt                                   0.0   0.0      0.0
# ...                                             ...   ...      ...
# The Hound of the Baskervilles.txt               0.0   0.0      0.0
# Romeo and Juliet.txt                            0.0   0.0      0.0
# The Blue Castle- a novel.txt                    0.0   0.0      0.0
# The Metamorphoses of Ovid.txt                   0.0   0.0      0.0
# The History of Woman Suffrage.txt               1.0   1.0      1.0
#
# [98 rows x 564119 columns]

# %% [markdown]
# ### Step 3: Binary Independence Model (BIM)
#
# Task: Implement a basic Binary Independence Model to rank documents.
#
# Requirements:
# * _Binary Representation:_ Represent the corpus and the query in binary vectors (1 if the term is present, 0 otherwise).
# * _Probability Estimation:_ Assume arbitrary probabilities for the presence of each term in relevant and non-relevant documents.
# * _Relevance Scoring:_ Calculate the relevance score for each document based on the product of probabilities for terms present in the query.
# * _Ranking:_ Rank the documents based on their relevance scores from highest to lowest.

# %%
df = df.transpose()

# %%
df
# Out:
#                   A Room with a View.txt  Chronicles of London Bridge.txt  \
# ﻿the                                 1.0                              1.0
# project                             83.0                             84.0
# gutenberg                           25.0                             25.0
# ebook                                8.0                              8.0
# of                                1435.0                           9664.0
# ...                                  ...                              ...
# 1091                                 0.0                              0.0
# encouragment                         0.0                              0.0
# -->encouragement                     0.0                              0.0
# 1094                                 0.0                              0.0
# atorney                              0.0                              0.0
#
#                   Winnie-the-Pooh.txt  The Enchanted April.txt  Moby Dick.txt  \
# ﻿the                              1.0                      1.0            1.0
# project                          83.0                     83.0           87.0
# gutenberg                        25.0                     25.0           25.0
# ebook                             8.0                      8.0            8.0
# of                              507.0                   1842.0         6682.0
# ...                               ...                      ...            ...
# 1091                              0.0                      0.0            0.0
# encouragment                      0.0                      0.0            0.0
# -->encouragement                  0.0                      0.0            0.0
# 1094                              0.0                      0.0            0.0
# atorney                           0.0                      0.0            0.0
#
#                   A Doll's House.txt  \
# ﻿the                             1.0
# project                         83.0
# gutenberg                       25.0
# ebook                            8.0
# of                             514.0
# ...                              ...
# 1091                             0.0
# encouragment                     0.0
# -->encouragement                 0.0
# 1094                             0.0
# atorney                          0.0
#
#                   A Christmas Carol in Prose Being a Ghost Story of Christmas.txt  \
# ﻿the                                                            1.0
# project                                                        83.0
# gutenberg                                                      25.0
# ebook                                                           8.0
# of                                                            781.0
# ...                                                             ...
# 1091                                                            0.0
# encouragment                                                    0.0
# -->encouragement                                                0.0
# 1094                                                            0.0
# atorney                                                         0.0
#
#                   Ulysses.txt  The Brothers Karamazov.txt  \
# ﻿the                      1.0                         1.0
# project                  88.0                        83.0
# gutenberg                25.0                        25.0
# ebook                     9.0                         8.0
# of                     8221.0                      7335.0
# ...                       ...                         ...
# 1091                      0.0                         0.0
# encouragment              0.0                         0.0
# -->encouragement          0.0                         0.0
# 1094                      0.0                         0.0
# atorney                   0.0                         0.0
#
#                   Jane Eyre- An Autobiography.txt  ...  \
# ﻿the                                          1.0  ...
# project                                      84.0  ...
# gutenberg                                    25.0  ...
# ebook                                         8.0  ...
# of                                         4442.0  ...
# ...                                           ...  ...
# 1091                                          0.0  ...
# encouragment                                  0.0  ...
# -->encouragement                              0.0  ...
# 1094                                          0.0  ...
# atorney                                       0.0  ...
#
#                   A Smaller History of Rome.txt  \
# ﻿the                                        1.0
# project                                    93.0
# gutenberg                                  25.0
# ebook                                       8.0
# of                                       7792.0
# ...                                         ...
# 1091                                        0.0
# encouragment                                0.0
# -->encouragement                            0.0
# 1094                                        0.0
# atorney                                     0.0
#
#                   The Adventures of Ferdinand Count Fathom — Complete.txt  \
# ﻿the                                                            1.0
# project                                                        88.0
# gutenberg                                                      25.0
# ebook                                                           8.0
# of                                                           7342.0
# ...                                                             ...
# 1091                                                            0.0
# encouragment                                                    0.0
# -->encouragement                                                0.0
# 1094                                                            0.0
# atorney                                                         0.0
#
#                   The Count of Monte Cristo.txt  \
# ﻿the                                        1.0
# project                                    92.0
# gutenberg                                  26.0
# ebook                                       8.0
# of                                      12779.0
# ...                                         ...
# 1091                                        0.0
# encouragment                                0.0
# -->encouragement                            0.0
# 1094                                        0.0
# atorney                                     0.0
#
#                   John Dewey's logical theory.txt  \
# ﻿the                                          1.0
# project                                      83.0
# gutenberg                                    25.0
# ebook                                         8.0
# of                                         2648.0
# ...                                           ...
# 1091                                          0.0
# encouragment                                  0.0
# -->encouragement                              0.0
# 1094                                          0.0
# atorney                                       0.0
#
#                   Christopher Columbus and How He Received and Imparted the Spirit of Discovery.txt  \
# ﻿the                                                            1.0
# project                                                        92.0
# gutenberg                                                      25.0
# ebook                                                           8.0
# of                                                          10842.0
# ...                                                             ...
# 1091                                                            0.0
# encouragment                                                    0.0
# -->encouragement                                                0.0
# 1094                                                            0.0
# atorney                                                         0.0
#
#                   The Hound of the Baskervilles.txt  Romeo and Juliet.txt  \
# ﻿the                                            1.0                   1.0
# project                                        83.0                  84.0
# gutenberg                                      25.0                  26.0
# ebook                                           8.0                   8.0
# of                                           1719.0                 516.0
# ...                                             ...                   ...
# 1091                                            0.0                   0.0
# encouragment                                    0.0                   0.0
# -->encouragement                                0.0                   0.0
# 1094                                            0.0                   0.0
# atorney                                         0.0                   0.0
#
#                   The Blue Castle- a novel.txt  The Metamorphoses of Ovid.txt  \
# ﻿the                                       1.0                            1.0
# project                                   83.0                           83.0
# gutenberg                                 25.0                           25.0
# ebook                                      8.0                            8.0
# of                                      1591.0                         5601.0
# ...                                        ...                            ...
# 1091                                       0.0                            0.0
# encouragment                               0.0                            0.0
# -->encouragement                           0.0                            0.0
# 1094                                       0.0                            0.0
# atorney                                    0.0                            0.0
#
#                   The History of Woman Suffrage.txt
# ﻿the                                            1.0
# project                                        86.0
# gutenberg                                      25.0
# ebook                                           8.0
# of                                          23106.0
# ...                                             ...
# 1091                                            1.0
# encouragment                                    1.0
# -->encouragement                                1.0
# 1094                                            1.0
# atorney                                         1.0
#
# [564119 rows x 98 columns]
